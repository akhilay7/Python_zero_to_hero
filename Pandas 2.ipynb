# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\hp\Downloads\python\pokemon_data.csv')
#print(df.tail(6))

#df = pd.read_csv(r'C:\Users\hp\Downloads\python\pokemon_data.txt', delimiter ='\t')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#print(df.columns) # read column names 

#print(df[['Name', 'Attack','Speed']][0:4]) # read each column

#print(df.iloc[0:6]) # read rows 

#print(df.iloc[5,1]) # read a specfic location

#for index , rows in df.iterrows():            # read rows 
    #print(index, rows['Name'])

#df.loc[df['Type 1']=="Fire"] 

#df.loc[(df['Type 1'] == "Fire") & (df['Speed'] > 80) & (df["Type 2"]=="Flying")]        # and & , Or | conditions

#df.describe()

#df.sort_values('Type 1', ascending=True)

#df.sort_values(['Name','Type 1','HP'], ascending=[1,0, 1])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#making changes to data 

#df['Total'] = df['Speed'] + df['Attack'] 
#df['Total']=df.iloc[:,4:9].sum(axis=1)

#df=df.drop(columns=['Total'])

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    273
# 1       80     60           1      False    345
# 2      100     80           1      False    445
# 3      120     80           1      False    545
# 4       50     65           1      False    244

# %%
#df.to_csv('modfied.csv',index=False)

#df.to_xlsx('modfied.xlsx',index=False)
#df.to_csv('modfiled.txt', index=False, sep='\t')

# %%
#new_df= df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]

#new_df.to_csv('filtered.csv')

#new_df.reset_index(drop=True, inplace=True)

df.loc[(df['Name'].str.contains('Mega')) & (df['Type 1'].str.contains('Gra')) & (df['HP']<100)]

#new_df
# Out:
#        #                     Name Type 1  Type 2  HP  Attack  Defense  \
# 3      3    VenusaurMega Venusaur  Grass  Poison  80     100      123
# 168  154                 Meganium  Grass     NaN  80      82      100
# 275  254    SceptileMega Sceptile  Grass  Dragon  70     110       75
# 511  460  AbomasnowMega Abomasnow  Grass     Ice  90     132      105
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3        122      120     80           1      False
# 168       83      100     80           2      False
# 275      145       85    145           3      False
# 511      132      105     30           4      False

# %%
import re 

#df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]

#df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I ,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
#df.loc[df['Type 1']=='whatever','Type 1']='Grass'

#df.loc[(df['Type 1'] == 'Grass') & (df['Speed']==45),'Attack']='49'

#df.loc[(df['Type 1'] == 'Grass') & (df['Speed']==45),['Attack' ,'Defense']]=[100, 200]


# df= pd.read('modifed.csv')
# Out:
# [100, 200]

# %%
#df.groupby(['Type 1']).mean(numeric_only=True)
#df.groupby(['Type 1'])[['HP', 'Attack']].mean(numeric_only=True).sort_values(['HP','Type 1'], ascending=False)

#df.groupby(['Type 1']).sum()

#df.groupby(['Type 1']).count()

df['Count']=1

df.groupby(['Type 1', 'Type 2','HP']).count()['Count']
# Out:
# Type 1  Type 2    HP
# Bug     Electric  50     1
#                   70     1
#         Fighting  80     2
#         Fire      55     1
#                   85     1
#                         ..
# Water   Rock      54     1
#                   55     1
#                   74     1
#                   100    1
#         Steel     84     1
# Name: Count, Length: 343, dtype: int64

# %%
new_df=pd.DataFrame(columns=df.columns)

for df in pd.read_csv(r'C:\Users\hp\Downloads\python\pokemon_data.csv', chunksize=20):
    results=df.groupby(['Type 1']).count()

    new_df=pd.concat([new_df, results])
    print(new_df)
# Out:
#        # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Bug    7    7    NaN      5  7      7       7       7       7     7
# Fire   5    5    NaN      3  5      5       5       5       5     5
# Grass  4    4    NaN      4  4      4       4       4       4     4
# Water  4    4    NaN      0  4      4       4       4       4     4
#
#       Generation Legendary
# Bug            7         7
# Fire           5         5
# Grass          4         4
# Water          4         4
#           # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Bug       7    7    NaN      5  7      7       7       7       7     7
# Fire      5    5    NaN      3  5      5       5       5       5     5
# Grass     4    4    NaN      4  4      4       4       4       4     4
# Water     4    4    NaN      0  4      4       4       4       4     4
# Electric  2    2    NaN      0  2      2       2       2       2     2
# ...
